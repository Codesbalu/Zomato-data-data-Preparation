# %% [markdown]
# ## **1. 📊 Introduction to Pandas**
#
# Pandas is a powerful library for data manipulation and analysis in Python. It builds on top of <font color="greed">NumPy</font> and provides easy-to-use data structures and functions for handling structured data. 🚀
#
# ### **Why Use Pandas?**
# 1. **Real-World Relevance**: Pandas helps analyze large datasets efficiently, such as customer reviews, financial data, or restaurant data like our **Zomato Bangalore dataset**.
# 2. **Core Strengths**:
#    - Data cleaning, preparation, and exploration.
#    - Supports handling **missing data**.
#    - Integrates seamlessly with libraries like <font color="magenta">Matplotlib</font> and <font color="magenta">NumPy</font>.
#
#
#
#
# **Installing Pandas**
# To install Pandas, use the following command:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Loading the data set

# %%
# !wget  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# !unzip zomato_dataset.zip
# !mv zomato_dataset.csv
# Out:
# --2025-12-27 10:06:28--  https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/100/375/original/zomato_dataset.zip
# Resolving d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)... 52.85.30.42, 52.85.30.133, 52.85.30.49, ...
# Connecting to d2beiqkhq929f0.cloudfront.net (d2beiqkhq929f0.cloudfront.net)|52.85.30.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72602133 (69M) [application/zip]
# Saving to: ‘zomato_dataset.zip.3’
#
# zomato_dataset.zip. 100%[===================>]  69.24M   101MB/s    in 0.7s
#
# 2025-12-27 10:06:29 (101 MB/s) - ‘zomato_dataset.zip.3’ saved [72602133/72602133]
#
# Archive:  zomato_dataset.zip
# replace zomato_dataset.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: mv: missing destination file operand after 'zomato_dataset.csv'
# Try 'mv --help' for more information.

# %%
import pandas as pd
df=pd.read_csv('zomato_dataset.csv')
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                     '800.0'
# 1     Chinese, North Indian, Thai                     '800.0'
# 2          Cafe, Mexican, Italian                     '800.0'
# 3      South Indian, North Indian                     '300.0'
# 4        North Indian, Rajasthani                     '600.0'
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   rate                         23193 non-null  object
#  6   votes                        23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
#  13  reviews_list                 23193 non-null  object
#  14  menu_item                    23193 non-null  object
#  15  listed_in(type)              23193 non-null  object
#  16  listed_in(city)              23193 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 3.0+ MB

# %% [markdown]
# `df.info()` gives a list of columns with:
#
# - **Name** of columns
# - **How many non-null values (blank cells)** each column has.
# - **Type of values** in each column - int, float, etc.
#
# **By default**, it shows **Dtype** as `object` for anything other than **int or float**.

# %% [markdown]
# ### **1. DataFrame**
# A <font color="skyblue">DataFrame</font> is a two-dimensional table with labeled rows and columns. It is the core structure in Pandas, ideal for tabular data like the Zomato dataset.
#
# 💡 **Key Features**:
# - Can hold data of different types (strings, integers, floats, etc.).
# - Labeled rows (**index**) and columns.
# - Provides tools for filtering, aggregating, and transforming data.
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/065/849/original/download.png?1708489323">

# %%
df['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 23188    3.8 /5
# 23189    3.9 /5
# 23190    2.8 /5
# 23191    2.5 /5
# 23192    4.3 /5
# Name: rate, Length: 23193, dtype: object

# %%
# Creating a DataFrame from a dictionary
data = {
    "Restaurant": ["R1", "R2", "R3"],
    "Votes": [120, 240, 150],
    "Rating": [4.1, 4.5, 3.9]
}

restaurant_df = pd.DataFrame(data)
restaurant_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9

# %%
restaurant_df.shape
# Out:
# (3, 3)

# %% [markdown]
# similar to numpy ,it gives the no.of rows and columns

# %%
type(data['Votes'])
# Out:
# list

# %%
type(restaurant_df['Votes'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### **2. Series**
# A <font color="green">Series</font> is a one-dimensional labeled array that can hold any data type. Think of it as a **single column of data** in a table.
#
# 💡 **Key Features**:
# - Data is labeled using an **index**.
# - Supports operations like indexing, slicing, and filtering.
#
# <img src="https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/065/850/original/download_%281%29.png?1708489343">

# %%
# Creating a Series from a list
restaurant_votes = pd.Series([120, 240, 150, 80], index=['R1', 'R2', 'R3', 'R4'])
print(restaurant_votes)
# Out:
# R1    120
# R2    240
# R3    150
# R4     80
# dtype: int64

# %%
print(restaurant_votes['R2'])
# Out:
# 240

# %% [markdown]
# 3.🔍 Basic Operations on Columns
# Columns in a Pandas DataFrame represent individual data features.
#
# Accessing Columns
# You can access columns using:
#
# Dot notation: df.column_name
# Bracket notation: df["column_name"]

# %%
votes=df['votes']
print(votes)
# Out:
# 0        775
# 1        787
# 2        918
# 3         88
# 4        166
#         ...
# 23188    128
# 23189     77
# 23190    161
# 23191     81
# 23192    236
# Name: votes, Length: 23193, dtype: int64

# %%
rating=df.rate
rating
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 23188    3.8 /5
# 23189    3.9 /5
# 23190    2.8 /5
# 23191    2.5 /5
# 23192    4.3 /5
# Name: rate, Length: 23193, dtype: object

# %%
df[['url','name']]
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                     name
# 0                                                  Jalsa
# 1                                         Spice Elephant
# 2                                        San Churro Cafe
# 3                                  Addhuri Udupi Bhojana
# 4                                          Grand Village
# ...                                                  ...
# 23188                                 Izakaya Gastro Pub
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield
# 23190                             Keys Cafe - Keys Hotel
# 23191                                            Bhagini
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...
#
# [23193 rows x 2 columns]

# %% [markdown]
# renaming columns

# %%
df=df.rename(columns={'votes':'Total_votes','rate':'Ratings'})
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# 2          Yes         No   3.8/5          918
# 3           No         No   3.7/5           88
# 4           No         No   3.8/5          166
#
#                               phone      location            rest_type  \
# 0    080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                      080 41714161  Banashankari        Casual Dining
# 2                    +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                    +91 9620009302  Banashankari          Quick Bites
# 4  +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                     '800.0'
# 1     Chinese, North Indian, Thai                     '800.0'
# 2          Cafe, Mexican, Italian                     '800.0'
# 3      South Indian, North Indian                     '300.0'
# 4        North Indian, Rajasthani                     '600.0'
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   Ratings                      23193 non-null  object
#  6   Total_votes                  23193 non-null  int64
#  7   phone                        23193 non-null  object
#  8   location                     23193 non-null  object
#  9   rest_type                    23193 non-null  object
#  10  dish_liked                   23193 non-null  object
#  11  cuisines                     23193 non-null  object
#  12  approx_cost(for two people)  23193 non-null  object
#  13  reviews_list                 23193 non-null  object
#  14  menu_item                    23193 non-null  object
#  15  listed_in(type)              23193 non-null  object
#  16  listed_in(city)              23193 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 3.0+ MB

# %% [markdown]
# 💡 **Key Point**: Rename ensures clarity, especially when column names are too short or unclear or have some formatting errors.
#
#
#
# ### **Adding a New Column**
# Add a new column by assigning data to a new column name.

# %%
df['only_rating']=[i[:-2] for i in df['Ratings']]
df['only_rating']
# Out:
# 0         4.1
# 1         4.1
# 2         3.8
# 3         3.7
# 4         3.8
#          ...
# 23188    3.8
# 23189    3.9
# 23190    2.8
# 23191    2.5
# 23192    4.3
# Name: only_rating, Length: 23193, dtype: object

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table Ratings  Total_votes  \
# 0          Yes        Yes   4.1/5          775
# 1          Yes         No   4.1/5          787
# 2          Yes         No   3.8/5          918
# 3           No         No   3.7/5           88
# 4           No         No   3.8/5          166
#
#                               phone      location            rest_type  \
# 0    080 42297555\r\n+91 9743772233  Banashankari        Casual Dining
# 1                      080 41714161  Banashankari        Casual Dining
# 2                    +91 9663487993  Banashankari  Cafe, Casual Dining
# 3                    +91 9620009302  Banashankari          Quick Bites
# 4  +91 8026612447\r\n+91 9901210005  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                     '800.0'
# 1     Chinese, North Indian, Thai                     '800.0'
# 2          Cafe, Mexican, Italian                     '800.0'
# 3      South Indian, North Indian                     '300.0'
# 4        North Indian, Rajasthani                     '600.0'
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city) only_rating
# 0          Buffet    Banashankari         4.1
# 1          Buffet    Banashankari         4.1
# 2          Buffet    Banashankari         3.8
# 3          Buffet    Banashankari         3.7
# 4          Buffet    Banashankari         3.8

# %%
df['total_votes_by_1000']=df['Total_votes']/1000
df['total_votes_by_1000']
# Out:
# 0        0.775
# 1        0.787
# 2        0.918
# 3        0.088
# 4        0.166
#          ...
# 23188    0.128
# 23189    0.077
# 23190    0.161
# 23191    0.081
# 23192    0.236
# Name: total_votes_by_1000, Length: 23193, dtype: float64

# %%
df['is_good']=df['Total_votes']>500
df['is_good']
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23188    False
# 23189    False
# 23190    False
# 23191    False
# 23192    False
# Name: is_good, Length: 23193, dtype: bool

# %% [markdown]
# ### **Deleting a Column**
#
# Use `df.drop()` to delete one or more columns:
# - Set `axis=1` to indicate column deletion.
# - Use `inplace=True` to modify the original DataFrame.

# %%
df.drop('Ratings',axis=1,inplace=True)
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  Total_votes                             phone  \
# 0          Yes        Yes          775    080 42297555\r\n+91 9743772233
# 1          Yes         No          787                      080 41714161
# 2          Yes         No          918                    +91 9663487993
# 3           No         No           88                    +91 9620009302
# 4           No         No          166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                     '800.0'
# 1     Chinese, North Indian, Thai                     '800.0'
# 2          Cafe, Mexican, Italian                     '800.0'
# 3      South Indian, North Indian                     '300.0'
# 4        North Indian, Rajasthani                     '600.0'
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city) only_rating  total_votes_by_1000  is_good
# 0          Buffet    Banashankari         4.1                0.775     True
# 1          Buffet    Banashankari         4.1                0.787     True
# 2          Buffet    Banashankari         3.8                0.918     True
# 3          Buffet    Banashankari         3.7                0.088    False
# 4          Buffet    Banashankari         3.8                0.166    False

# %% [markdown]
# ### **Unique Values in a Column**
#
# The `df["column_name"].unique()` method lists unique values in a column.

# %%
unique_ratings=df['cuisines'].unique()
unique_ratings
# Out:
# array(['North Indian, Mughlai, Chinese', 'Chinese, North Indian, Thai',
#        'Cafe, Mexican, Italian', ..., 'Andhra, Hyderabadi, Biryani',
#        'Andhra, North Indian, South Indian', 'Thai, Chinese, Momos'],
#       dtype=object)

# %%
num_of_res=df['name'].nunique()
num_of_res
# Out:
# 3159

# %% [markdown]
# ### **Value Counts in a Column**
#
# The `df["column_name"].value_counts()` method counts occurrences of each unique value.

# %%
rating_counts=df['only_rating'].value_counts()
rating_counts
# Out:
# only_rating
# 3.9     1689
# 3.9     1549
# 4.0     1469
# 4.1     1398
# 4.0     1391
#         ...
# 2.2        7
# 2.0        7
# 2.0        4
# 1.8        3
# 1.8        2
# Name: count, Length: 63, dtype: int64

# %%
rating_counts['N']
# Out:
# np.int64(147)

# %% [markdown]
# ther are total 4 nukl values in this column

# %% [markdown]
# Question: Which is the most ordered restaurant in the dataset?

# %%
restaurant_order_counts=df['name'].value_counts()
restaurant_order_counts
# Out:
# name
# Onesta               85
# Empire Restaurant    69
# KFC                  59
# McDonald's           57
# Pizza Hut            56
#                      ..
# Bao & Grills          1
# Gongura               1
# Tuk-Tuk               1
# Karibu - The Zuri     1
# Fujian Express        1
# Name: count, Length: 3159, dtype: int64

# %% [markdown]
# Which city has the most restaurants listed in the dataset?

# %%
city_counts=df['location'].value_counts()
city_counts
# Out:
# location
# Koramangala 5th Block    1783
# BTM                      1456
# Indiranagar              1350
# HSR                      1162
# Jayanagar                1037
#                          ...
# Kanakapura Road             2
# West Bangalore              2
# Yelahanka                   2
# Magadi Road                 2
# KR Puram                    1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# Which type of listing (e.g., delivery, dine-out, etc.) is the most common?

# %%
listing_counts = df['listed_in(type)'].value_counts()
listing_counts
# Out:
# listed_in(type)
# Delivery              10625
# Dine-out               8009
# Desserts               1333
# Cafes                  1047
# Drinks & nightlife      890
# Buffet                  762
# Pubs and bars           527
# Name: count, dtype: int64

# %% [markdown]
# ---
#
# ## **4. 🧱 Operations on Rows**

# %% [markdown]
# ### **Understanding Index in a DataFrame**
#
# Every row in a DataFrame has an **index**, which uniquely identifies the row.
#
# Indexing is critical for:
# 1. Accessing specific rows.
# 2. Slicing multiple rows.
# 3. Efficient filtering and data manipulation.
#
# 💡 **Key Types of Indexing:**
# 1. **Implicit Index**: The default integer-based row indices (`0, 1, 2, ...`).
# 2. **Explicit Index**: Custom labels you assign to rows (e.g., names or IDs).

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=23193, step=1)

# %% [markdown]
# ### **Implicit vs. Explicit Indexing**
#
# - **Implicit Index**: Automatically generated when creating a DataFrame.
#   - Example: `0, 1, 2, 3, ...`
# - **Explicit Index**: Custom-defined indices based on the dataset's context.
#   - Example: Using `Restaurant` names or `City` names as indices.
#
# You can assign an explicit index using the `set_index()` method:

# %%
df_explicit=df.set_index('name')
df_explicit
# Out:
#                                                                                                   url  \
# name
# Jalsa                                               https://www.zomato.com/bangalore/jalsa-banasha...
# Spice Elephant                                      https://www.zomato.com/bangalore/spice-elephan...
# San Churro Cafe                                     https://www.zomato.com/SanchurroBangalore?cont...
# Addhuri Udupi Bhojana                               https://www.zomato.com/bangalore/addhuri-udupi...
# Grand Village                                       https://www.zomato.com/bangalore/grand-village...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  https://www.zomato.com/bangalore/izakaya-gastr...
# M Bar - Bengaluru Marriott Hotel Whitefield         https://www.zomato.com/bangalore/m-bar-bengalu...
# Keys Cafe - Keys Hotel                              https://www.zomato.com/bangalore/keys-cafe-key...
# Bhagini                                             https://www.zomato.com/bangalore/bhagini-2-whi...
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                                                               address  \
# name
# Jalsa                                               942, 21st Main Road, 2nd Stage, Banashankari, ...
# Spice Elephant                                      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# San Churro Cafe                                     1112, Next to KIMS Medical College, 17th Cross...
# Addhuri Udupi Bhojana                               1st Floor, Annakuteera, 3rd Stage, Banashankar...
# Grand Village                                       10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# M Bar - Bengaluru Marriott Hotel Whitefield         Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# Keys Cafe - Keys Hotel                              Keys Hotel, 6, 1st Phase Industrial Area, Near...
# Bhagini                                             139/C1, Next To GR Tech Park, Pattandur Agraha...
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                    online_order book_table  \
# name
# Jalsa                                                       Yes        Yes
# Spice Elephant                                              Yes         No
# San Churro Cafe                                             Yes         No
# Addhuri Udupi Bhojana                                        No         No
# Grand Village                                                No         No
# ...                                                         ...        ...
# Izakaya Gastro Pub                                          Yes        Yes
# M Bar - Bengaluru Marriott Hotel Whitefield                  No         No
# Keys Cafe - Keys Hotel                                       No         No
# Bhagini                                                      No         No
# Chime - Sheraton Grand Bengaluru Whitefield Hot...           No        Yes
#
#                                                     Total_votes  \
# name
# Jalsa                                                       775
# Spice Elephant                                              787
# San Churro Cafe                                             918
# Addhuri Udupi Bhojana                                        88
# Grand Village                                               166
# ...                                                         ...
# Izakaya Gastro Pub                                          128
# M Bar - Bengaluru Marriott Hotel Whitefield                  77
# Keys Cafe - Keys Hotel                                      161
# Bhagini                                                      81
# Chime - Sheraton Grand Bengaluru Whitefield Hot...          236
#
#                                                                                phone  \
# name
# Jalsa                                                 080 42297555\r\n+91 9743772233
# Spice Elephant                                                          080 41714161
# San Churro Cafe                                                       +91 9663487993
# Addhuri Udupi Bhojana                                                 +91 9620009302
# Grand Village                                       +91 8026612447\r\n+91 9901210005
# ...                                                                              ...
# Izakaya Gastro Pub                                    +91 7625087121\n+91 8050587483
# M Bar - Bengaluru Marriott Hotel Whitefield                             080 49435000
# Keys Cafe - Keys Hotel                                  080 39451000\n+91 8884038484
# Bhagini                                                                 080 65951222
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                      080 49652769
#
#                                                                       location  \
# name
# Jalsa                                                             Banashankari
# Spice Elephant                                                    Banashankari
# San Churro Cafe                                                   Banashankari
# Addhuri Udupi Bhojana                                             Banashankari
# Grand Village                                                     Basavanagudi
# ...                                                                        ...
# Izakaya Gastro Pub                                                  Whitefield
# M Bar - Bengaluru Marriott Hotel Whitefield                         Whitefield
# Keys Cafe - Keys Hotel                                              Whitefield
# Bhagini                                                             Whitefield
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  ITPL Main Road, Whitefield
#
#                                                               rest_type  \
# name
# Jalsa                                                     Casual Dining
# Spice Elephant                                            Casual Dining
# San Churro Cafe                                     Cafe, Casual Dining
# Addhuri Udupi Bhojana                                       Quick Bites
# Grand Village                                             Casual Dining
# ...                                                                 ...
# Izakaya Gastro Pub                                   Bar, Casual Dining
# M Bar - Bengaluru Marriott Hotel Whitefield            Fine Dining, Bar
# Keys Cafe - Keys Hotel                               Casual Dining, Bar
# Bhagini                                              Casual Dining, Bar
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                  Bar
#
#                                                                                            dish_liked  \
# name
# Jalsa                                               Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Spice Elephant                                      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# San Churro Cafe                                     Churros, Cannelloni, Minestrone Soup, Hot Choc...
# Addhuri Udupi Bhojana                                                                     Masala Dosa
# Grand Village                                                                     Panipuri, Gol Gappe
# ...                                                                                               ...
# Izakaya Gastro Pub                                  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# M Bar - Bengaluru Marriott Hotel Whitefield                                          Rooftop Ambience
# Keys Cafe - Keys Hotel                              Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# Bhagini                                                                          Biryani, Andhra Meal
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                       Cocktails, Pizza, Buttermilk
#
#                                                                                        cuisines  \
# name
# Jalsa                                                            North Indian, Mughlai, Chinese
# Spice Elephant                                                      Chinese, North Indian, Thai
# San Churro Cafe                                                          Cafe, Mexican, Italian
# Addhuri Udupi Bhojana                                                South Indian, North Indian
# Grand Village                                                          North Indian, Rajasthani
# ...                                                                                         ...
# Izakaya Gastro Pub                                     North Indian, Continental, Mediterranean
# M Bar - Bengaluru Marriott Hotel Whitefield                                         Finger Food
# Keys Cafe - Keys Hotel                                       Chinese, Continental, North Indian
# Bhagini                                             Andhra, South Indian, Chinese, North Indian
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                                  Finger Food
#
#                                                    approx_cost(for two people)  \
# name
# Jalsa                                                                  '800.0'
# Spice Elephant                                                         '800.0'
# San Churro Cafe                                                        '800.0'
# Addhuri Udupi Bhojana                                                  '300.0'
# Grand Village                                                          '600.0'
# ...                                                                        ...
# Izakaya Gastro Pub                                                    '1200.0'
# M Bar - Bengaluru Marriott Hotel Whitefield                           '2000.0'
# Keys Cafe - Keys Hotel                                                '1200.0'
# Bhagini                                                                '800.0'
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                    '2500.0'
#
#                                                                                          reviews_list  \
# name
# Jalsa                                               [('Rated 4.0', 'RATED\n  A beautiful place to ...
# Spice Elephant                                      [('Rated 4.0', 'RATED\n  Had been here for din...
# San Churro Cafe                                     [('Rated 3.0', "RATED\n  Ambience is not that ...
# Addhuri Udupi Bhojana                               [('Rated 4.0', "RATED\n  Great food and proper...
# Grand Village                                       [('Rated 4.0', 'RATED\n  Very good restaurant ...
# ...                                                                                               ...
# Izakaya Gastro Pub                                  [('Rated 3.0', "RATED\n  Nice place to hangout...
# M Bar - Bengaluru Marriott Hotel Whitefield         [('Rated 4.0', 'RATED\n  Went there post dinne...
# Keys Cafe - Keys Hotel                              [('Rated 3.0', 'RATED\n  Place is good not tha...
# Bhagini                                             [('Rated 4.0', 'RATED\n  A fine place to chill...
# Chime - Sheraton Grand Bengaluru Whitefield Hot...  [('Rated 4.0', 'RATED\n  Nice and friendly pla...
#
#                                                    menu_item listed_in(type)  \
# name
# Jalsa                                                     []          Buffet
# Spice Elephant                                            []          Buffet
# San Churro Cafe                                           []          Buffet
# Addhuri Udupi Bhojana                                     []          Buffet
# Grand Village                                             []          Buffet
# ...                                                      ...             ...
# Izakaya Gastro Pub                                        []   Pubs and bars
# M Bar - Bengaluru Marriott Hotel Whitefield               []   Pubs and bars
# Keys Cafe - Keys Hotel                                    []   Pubs and bars
# Bhagini                                                   []   Pubs and bars
# Chime - Sheraton Grand Bengaluru Whitefield Hot...        []   Pubs and bars
#
#                                                    listed_in(city)  \
# name
# Jalsa                                                 Banashankari
# Spice Elephant                                        Banashankari
# San Churro Cafe                                       Banashankari
# Addhuri Udupi Bhojana                                 Banashankari
# Grand Village                                         Banashankari
# ...                                                            ...
# Izakaya Gastro Pub                                      Whitefield
# M Bar - Bengaluru Marriott Hotel Whitefield             Whitefield
# Keys Cafe - Keys Hotel                                  Whitefield
# Bhagini                                                 Whitefield
# Chime - Sheraton Grand Bengaluru Whitefield Hot...      Whitefield
#
#                                                    only_rating  \
# name
# Jalsa                                                      4.1
# Spice Elephant                                             4.1
# San Churro Cafe                                            3.8
# Addhuri Udupi Bhojana                                      3.7
# Grand Village                                              3.8
# ...                                                        ...
# Izakaya Gastro Pub                                        3.8
# M Bar - Bengaluru Marriott Hotel Whitefield               3.9
# Keys Cafe - Keys Hotel                                    2.8
# Bhagini                                                   2.5
# Chime - Sheraton Grand Bengaluru Whitefield Hot...        4.3
#
#                                                     total_votes_by_1000  \
# name
# Jalsa                                                             0.775
# Spice Elephant                                                    0.787
# San Churro Cafe                                                   0.918
# Addhuri Udupi Bhojana                                             0.088
# Grand Village                                                     0.166
# ...                                                                 ...
# Izakaya Gastro Pub                                                0.128
# M Bar - Bengaluru Marriott Hotel Whitefield                       0.077
# Keys Cafe - Keys Hotel                                            0.161
# Bhagini                                                           0.081
# Chime - Sheraton Grand Bengaluru Whitefield Hot...                0.236
#
#                                                     is_good
# name
# Jalsa                                                  True
# Spice Elephant                                         True
# San Churro Cafe                                        True
# Addhuri Udupi Bhojana                                 False
# Grand Village                                         False
# ...                                                     ...
# Izakaya Gastro Pub                                    False
# M Bar - Bengaluru Marriott Hotel Whitefield           False
# Keys Cafe - Keys Hotel                                False
# Bhagini                                               False
# Chime - Sheraton Grand Bengaluru Whitefield Hot...    False
#
# [23193 rows x 18 columns]

# %%
df_explicit.index
# Out:
# Index(['Jalsa', 'Spice Elephant', 'San Churro Cafe', 'Addhuri Udupi Bhojana',
#        'Grand Village', 'Timepass Dinner', 'Onesta', 'Penthouse Cafe',
#        'Smacznego', 'CafÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ© Down The Alley',
#        ...
#        'BAR BAR', 'The Beer Cafe', 'Pablo's Gastrobar', 'Oliver's Pub & Diner',
#        'Smaaash', 'Izakaya Gastro Pub',
#        'M Bar - Bengaluru Marriott Hotel Whitefield', 'Keys Cafe - Keys Hotel',
#        'Bhagini', 'Chime - Sheraton Grand Bengaluru Whitefield Hotel &...'],
#       dtype='object', name='name', length=23193)

# %% [markdown]
# ### **Slicing Rows**
#
# Rows can be sliced using implicit or explicit indices. Pandas provides two key tools for slicing:
#
# 1. **`.iloc`**: Slicing based on implicit integer indices.
# 2. **`.loc`**: Slicing based on explicit indices.
#
#
#
# **Slicing Rows with `.iloc`**
#
# Use `.iloc` for row selection by integer position:

# %%
df.iloc[0]
# Out:
# url                            https://www.zomato.com/bangalore/jalsa-banasha...
# address                        942, 21st Main Road, 2nd Stage, Banashankari, ...
# name                                                                       Jalsa
# online_order                                                                 Yes
# book_table                                                                   Yes
# Total_votes                                                                  775
# phone                                             080 42297555\r\n+91 9743772233
# location                                                            Banashankari
# rest_type                                                          Casual Dining
# dish_liked                     Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# cuisines                                          North Indian, Mughlai, Chinese
# approx_cost(for two people)                                              '800.0'
# reviews_list                   [('Rated 4.0', 'RATED\n  A beautiful place to ...
# menu_item                                                                     []
# listed_in(type)                                                           Buffet
# listed_in(city)                                                     Banashankari
# only_rating                                                                  4.1
# total_votes_by_1000                                                        0.775
# is_good                                                                     True
# Name: 0, dtype: object

# %%
df.iloc[1:3]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
#
#                                              address             name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table  Total_votes           phone      location  \
# 1          Yes         No          787    080 41714161  Banashankari
# 2          Yes         No          918  +91 9663487993  Banashankari
#
#              rest_type                                         dish_liked  \
# 1        Casual Dining  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Cafe, Casual Dining  Churros, Cannelloni, Minestrone Soup, Hot Choc...
#
#                       cuisines approx_cost(for two people)  \
# 1  Chinese, North Indian, Thai                     '800.0'
# 2       Cafe, Mexican, Italian                     '800.0'
#
#                                         reviews_list menu_item  \
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
#
#   listed_in(type) listed_in(city) only_rating  total_votes_by_1000  is_good
# 1          Buffet    Banashankari         4.1                0.787     True
# 2          Buffet    Banashankari         3.8                0.918     True

# %%
df.iloc[1:10:5]
# Out:
#                                                  url  \
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 6  https://www.zomato.com/bangalore/onesta-banash...
#
#                                              address            name  \
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice Elephant
# 6  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...          Onesta
#
#   online_order book_table  Total_votes                         phone  \
# 1          Yes         No          787                  080 41714161
# 6          Yes        Yes         2556  080 48653961\r\n080 48655715
#
#        location            rest_type  \
# 1  Banashankari        Casual Dining
# 6  Banashankari  Casual Dining, Cafe
#
#                                           dish_liked  \
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 6  Farmhouse Pizza, Chocolate Banana, Virgin Moji...
#
#                       cuisines approx_cost(for two people)  \
# 1  Chinese, North Indian, Thai                     '800.0'
# 6         Pizza, Cafe, Italian                     '600.0'
#
#                                         reviews_list menu_item  \
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 6  [('Rated 5.0', 'RATED\n  I personally really l...        []
#
#   listed_in(type) listed_in(city) only_rating  total_votes_by_1000  is_good
# 1          Buffet    Banashankari         4.1                0.787     True
# 6           Cafes    Banashankari         4.6                2.556     True

# %%
df.iloc[-1]
# Out:
# url                            https://www.zomato.com/bangalore/chime-sherato...
# address                        Sheraton Grand Bengaluru Whitefield Hotel & Co...
# name                           Chime - Sheraton Grand Bengaluru Whitefield Ho...
# online_order                                                                  No
# book_table                                                                   Yes
# Total_votes                                                                  236
# phone                                                               080 49652769
# location                                              ITPL Main Road, Whitefield
# rest_type                                                                    Bar
# dish_liked                                          Cocktails, Pizza, Buttermilk
# cuisines                                                             Finger Food
# approx_cost(for two people)                                             '2500.0'
# reviews_list                   [('Rated 4.0', 'RATED\n  Nice and friendly pla...
# menu_item                                                                     []
# listed_in(type)                                                    Pubs and bars
# listed_in(city)                                                       Whitefield
# only_rating                                                                 4.3
# total_votes_by_1000                                                        0.236
# is_good                                                                    False
# Name: 23192, dtype: object

# %% [markdown]
# **slicing with .loc**c

# %%
df_explicit.loc['Jalsa']
# Out:
#                                                      url  \
# name
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa  https://www.zomato.com/bangalore/jalsa-maratha...
#
#                                                  address online_order  \
# name
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  25/7, Doddannakundi, Outer Ring Road, Mahadeva...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa  25/7, Doddannakundi, Outer Ring Road, Mahadeva...          Yes
#
#       book_table  Total_votes                                 phone  \
# name
# Jalsa        Yes          775        080 42297555\r\n+91 9743772233
# Jalsa        Yes          775        080 42297555\r\n+91 9743772233
# Jalsa        Yes          775  080 42297555\r\r\r\r\n+91 9743772233
# Jalsa        Yes          775        080 42297555\r\n+91 9743772233
# Jalsa        Yes          775        080 42297555\r\n+91 9743772233
# Jalsa        Yes          804          080 42297555\n+91 9743772233
# Jalsa        Yes         2173      +91 7406617555\r\n+91 7406627555
# Jalsa        Yes          783        080 42297555\r\n+91 9743772233
# Jalsa        Yes          783        080 42297555\r\n+91 9743772233
# Jalsa        Yes          783        080 42297555\r\n+91 9743772233
# Jalsa        Yes         2189        +91 7406617555\n+91 7406627555
#
#            location      rest_type  \
# name
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Marathahalli  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Banashankari  Casual Dining
# Jalsa  Marathahalli  Casual Dining
#
#                                               dish_liked  \
# name
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Paneer Lajawab, Masala Pa...
# Jalsa  Mutton Curry, Stuffed Mushroom, Laccha Paratha...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa  Mutton Curry, Stuffed Mushroom, Laccha Paratha...
#
#                              cuisines approx_cost(for two people)  \
# name
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa           North Indian, Mughlai                    '1500.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa  North Indian, Mughlai, Chinese                     '800.0'
# Jalsa           North Indian, Mughlai                    '1500.0'
#
#                                             reviews_list menu_item  \
# name
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  Super ambience\nGreat...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A pretty decent place...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa  [('Rated 4.0', 'RATED\n  Friendly staff, avera...        []
#
#       listed_in(type) listed_in(city) only_rating  total_votes_by_1000  \
# name
# Jalsa          Buffet    Banashankari         4.1                0.775
# Jalsa        Delivery    Banashankari         4.1                0.775
# Jalsa        Dine-out    Banashankari         4.1                0.775
# Jalsa          Buffet    Basavanagudi         4.1                0.775
# Jalsa        Delivery    Basavanagudi         4.1                0.775
# Jalsa        Dine-out    Basavanagudi        4.1                 0.804
# Jalsa        Delivery     Brookefield         4.2                2.173
# Jalsa          Buffet       Jayanagar         4.1                0.783
# Jalsa        Delivery       Jayanagar         4.1                0.783
# Jalsa        Dine-out       Jayanagar        4.1                 0.783
# Jalsa        Delivery    Marathahalli        4.2                 2.189
#
#        is_good
# name
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True
# Jalsa     True

# %%
df_explicit.loc[['Jalsa','Tuk-Tuk']]
# Out:
#                                                        url  \
# name
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-banasha...
# Jalsa    https://www.zomato.com/bangalore/jalsa-maratha...
# Tuk-Tuk  https://www.zomato.com/bangalore/tuk-tuk-white...
#
#                                                    address online_order  \
# name
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    25/7, Doddannakundi, Outer Ring Road, Mahadeva...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    942, 21st Main Road, 2nd Stage, Banashankari, ...          Yes
# Jalsa    25/7, Doddannakundi, Outer Ring Road, Mahadeva...          Yes
# Tuk-Tuk  2nd Floor, Food Court, VR Mall, Whitefield, Ba...           No
#
#         book_table  Total_votes                                 phone  \
# name
# Jalsa          Yes          775        080 42297555\r\n+91 9743772233
# Jalsa          Yes          775        080 42297555\r\n+91 9743772233
# Jalsa          Yes          775  080 42297555\r\r\r\r\n+91 9743772233
# Jalsa          Yes          775        080 42297555\r\n+91 9743772233
# Jalsa          Yes          775        080 42297555\r\n+91 9743772233
# Jalsa          Yes          804          080 42297555\n+91 9743772233
# Jalsa          Yes         2173      +91 7406617555\r\n+91 7406627555
# Jalsa          Yes          783        080 42297555\r\n+91 9743772233
# Jalsa          Yes          783        080 42297555\r\n+91 9743772233
# Jalsa          Yes          783        080 42297555\r\n+91 9743772233
# Jalsa          Yes         2189        +91 7406617555\n+91 7406627555
# Tuk-Tuk         No           36                        +91 8105882336
#
#              location      rest_type  \
# name
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Marathahalli  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Banashankari  Casual Dining
# Jalsa    Marathahalli  Casual Dining
# Tuk-Tuk    Whitefield     Food Court
#
#                                                 dish_liked  \
# name
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Paneer Lajawab, Masala Pa...
# Jalsa    Mutton Curry, Stuffed Mushroom, Laccha Paratha...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# Jalsa    Mutton Curry, Stuffed Mushroom, Laccha Paratha...
# Tuk-Tuk                                            Biryani
#
#                                cuisines approx_cost(for two people)  \
# name
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa             North Indian, Mughlai                    '1500.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa    North Indian, Mughlai, Chinese                     '800.0'
# Jalsa             North Indian, Mughlai                    '1500.0'
# Tuk-Tuk                    North Indian                     '400.0'
#
#                                               reviews_list menu_item  \
# name
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  Super ambience\nGreat...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A pretty decent place...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# Jalsa    [('Rated 4.0', 'RATED\n  Friendly staff, avera...        []
# Tuk-Tuk  [('Rated 4.0', "RATED\n  I like this place bec...        []
#
#         listed_in(type) listed_in(city) only_rating  total_votes_by_1000  \
# name
# Jalsa            Buffet    Banashankari         4.1                0.775
# Jalsa          Delivery    Banashankari         4.1                0.775
# Jalsa          Dine-out    Banashankari         4.1                0.775
# Jalsa            Buffet    Basavanagudi         4.1                0.775
# Jalsa          Delivery    Basavanagudi         4.1                0.775
# Jalsa          Dine-out    Basavanagudi        4.1                 0.804
# Jalsa          Delivery     Brookefield         4.2                2.173
# Jalsa            Buffet       Jayanagar         4.1                0.783
# Jalsa          Delivery       Jayanagar         4.1                0.783
# Jalsa          Dine-out       Jayanagar        4.1                 0.783
# Jalsa          Delivery    Marathahalli        4.2                 2.189
# Tuk-Tuk        Dine-out      Whitefield        2.7                 0.036
#
#          is_good
# name
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Jalsa       True
# Tuk-Tuk    False

# %% [markdown]
# **Key Methods for Row Operations**
#
# 1. **View Current Index**: `df.index`
# 2. **Change Index**: `df.set_index("column_name")`
# 3. **Access Rows by Position**: `df.iloc[]`
# 4. **Access Rows by Label**: `df.loc[]`
# 5. **Slice Rows**:
#    - Implicit Index: `df.iloc[start:end]`
#    - Explicit Index: `df.loc["label_start":"label_end"]`
#
#
#
# **How can we reset our indices back to integers?**

# %%
df.reset_index()
# Out:
#        index                                                url  \
# 0          0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1          1  https://www.zomato.com/bangalore/spice-elephan...
# 2          2  https://www.zomato.com/SanchurroBangalore?cont...
# 3          3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4          4  https://www.zomato.com/bangalore/grand-village...
# ...      ...                                                ...
# 23188  23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23190                             Keys Cafe - Keys Hotel           No
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  Total_votes                             phone  \
# 0            Yes          775    080 42297555\r\n+91 9743772233
# 1             No          787                      080 41714161
# 2             No          918                    +91 9663487993
# 3             No           88                    +91 9620009302
# 4             No          166  +91 8026612447\r\n+91 9901210005
# ...          ...          ...                               ...
# 23188        Yes          128    +91 7625087121\n+91 8050587483
# 23189         No           77                      080 49435000
# 23190         No          161      080 39451000\n+91 8884038484
# 23191         No           81                      080 65951222
# 23192        Yes          236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23188                  Whitefield   Bar, Casual Dining
# 23189                  Whitefield     Fine Dining, Bar
# 23190                  Whitefield   Casual Dining, Bar
# 23191                  Whitefield   Casual Dining, Bar
# 23192  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23188  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                   Rooftop Ambience
# 23190  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                               Biryani, Andhra Meal
# 23192                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 23188     North Indian, Continental, Mediterranean
# 23189                                  Finger Food
# 23190           Chinese, Continental, North Indian
# 23191  Andhra, South Indian, Chinese, North Indian
# 23192                                  Finger Food
#
#       approx_cost(for two people)  \
# 0                         '800.0'
# 1                         '800.0'
# 2                         '800.0'
# 3                         '300.0'
# 4                         '600.0'
# ...                           ...
# 23188                    '1200.0'
# 23189                    '2000.0'
# 23190                    '1200.0'
# 23191                     '800.0'
# 23192                    '2500.0'
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 23188  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 23189  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 23190  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 23191  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 23192  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city) only_rating  total_votes_by_1000  \
# 0              Buffet    Banashankari         4.1                0.775
# 1              Buffet    Banashankari         4.1                0.787
# 2              Buffet    Banashankari         3.8                0.918
# 3              Buffet    Banashankari         3.7                0.088
# 4              Buffet    Banashankari         3.8                0.166
# ...               ...             ...         ...                  ...
# 23188   Pubs and bars      Whitefield        3.8                 0.128
# 23189   Pubs and bars      Whitefield        3.9                 0.077
# 23190   Pubs and bars      Whitefield        2.8                 0.161
# 23191   Pubs and bars      Whitefield        2.5                 0.081
# 23192   Pubs and bars      Whitefield        4.3                 0.236
#
#        is_good
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
# ...        ...
# 23188    False
# 23189    False
# 23190    False
# 23191    False
# 23192    False
#
# [23193 rows x 20 columns]

# %%
df.reset_index(drop=True)
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23190                             Keys Cafe - Keys Hotel           No
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  Total_votes                             phone  \
# 0            Yes          775    080 42297555\r\n+91 9743772233
# 1             No          787                      080 41714161
# 2             No          918                    +91 9663487993
# 3             No           88                    +91 9620009302
# 4             No          166  +91 8026612447\r\n+91 9901210005
# ...          ...          ...                               ...
# 23188        Yes          128    +91 7625087121\n+91 8050587483
# 23189         No           77                      080 49435000
# 23190         No          161      080 39451000\n+91 8884038484
# 23191         No           81                      080 65951222
# 23192        Yes          236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23188                  Whitefield   Bar, Casual Dining
# 23189                  Whitefield     Fine Dining, Bar
# 23190                  Whitefield   Casual Dining, Bar
# 23191                  Whitefield   Casual Dining, Bar
# 23192  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23188  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                   Rooftop Ambience
# 23190  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                               Biryani, Andhra Meal
# 23192                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 23188     North Indian, Continental, Mediterranean
# 23189                                  Finger Food
# 23190           Chinese, Continental, North Indian
# 23191  Andhra, South Indian, Chinese, North Indian
# 23192                                  Finger Food
#
#       approx_cost(for two people)  \
# 0                         '800.0'
# 1                         '800.0'
# 2                         '800.0'
# 3                         '300.0'
# 4                         '600.0'
# ...                           ...
# 23188                    '1200.0'
# 23189                    '2000.0'
# 23190                    '1200.0'
# 23191                     '800.0'
# 23192                    '2500.0'
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 23188  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 23189  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 23190  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 23191  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 23192  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city) only_rating  total_votes_by_1000  \
# 0              Buffet    Banashankari         4.1                0.775
# 1              Buffet    Banashankari         4.1                0.787
# 2              Buffet    Banashankari         3.8                0.918
# 3              Buffet    Banashankari         3.7                0.088
# 4              Buffet    Banashankari         3.8                0.166
# ...               ...             ...         ...                  ...
# 23188   Pubs and bars      Whitefield        3.8                 0.128
# 23189   Pubs and bars      Whitefield        3.9                 0.077
# 23190   Pubs and bars      Whitefield        2.8                 0.161
# 23191   Pubs and bars      Whitefield        2.5                 0.081
# 23192   Pubs and bars      Whitefield        4.3                 0.236
#
#        is_good
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
# ...        ...
# 23188    False
# 23189    False
# 23190    False
# 23191    False
# 23192    False
#
# [23193 rows x 19 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table  Total_votes                             phone  \
# 0          Yes        Yes          775    080 42297555\r\n+91 9743772233
# 1          Yes         No          787                      080 41714161
# 2          Yes         No          918                    +91 9663487993
# 3           No         No           88                    +91 9620009302
# 4           No         No          166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                     '800.0'
# 1     Chinese, North Indian, Thai                     '800.0'
# 2          Cafe, Mexican, Italian                     '800.0'
# 3      South Indian, North Indian                     '300.0'
# 4        North Indian, Rajasthani                     '600.0'
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city) only_rating  total_votes_by_1000  is_good
# 0          Buffet    Banashankari         4.1                0.775     True
# 1          Buffet    Banashankari         4.1                0.787     True
# 2          Buffet    Banashankari         3.8                0.918     True
# 3          Buffet    Banashankari         3.7                0.088    False
# 4          Buffet    Banashankari         3.8                0.166    False

# %% [markdown]
# ---
#
# ## **5. 🎯 Working with Both Rows and Columns**
#
# When analyzing data, you often need to work with both rows and columns simultaneously. Pandas provides powerful tools for selecting, slicing, and filtering data across multiple axes.
#
# 💡 **Key Tools for Selection**:
# 1. **`.iloc`**: Select rows and columns by integer position.
# 2. **`.loc`**: Select rows and columns by labels.
#
#
# ### **Using `.iloc` for Rows and Columns**
#
# The `.iloc` method allows you to:
# 1. Select specific rows and columns by their integer indices.
# 2. Slice rows and columns together.
#
# #### Example: Selecting Specific Rows and Columns

# %%
df.iloc[0:2,0:2]
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...

# %%
df.iloc[-2:,-1]
# Out:
# 23191    False
# 23192    False
# Name: is_good, dtype: bool

# %%
data = {
    "Restaurant": ["R1", "R2", "R3", "R4"],
    "Votes": [120, 240, 150, 80],
    "Rating": [4.1, 4.5, 3.9, 4.0]
}

sample_df=pd.DataFrame(data)
sample_df.iloc[1:3,1:3]=[[300,4.7],[180,4.2]]

print(sample_df)
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0

# %%
df_explicit=sample_df.set_index('Restaurant')
df_explicit.loc[['R1','R3'],['Votes']]
# Out:
#             Votes
# Restaurant
# R1            120
# R3            180

# %%
df_explicit
# Out:
#             Votes  Rating
# Restaurant
# R1            120     4.1
# R2            320     4.7
# R3            180     4.2
# R4             80     4.0

# %% [markdown]
# **4. Using `.loc` for Conditional Updates**

# %% [markdown]
# ### ✂️ Combining DataFrames with `concat`
#
# The `concat` function allows you to combine multiple DataFrames:
# 1. **Row-wise Concatenation**: Add rows from another DataFrame.
# 2. **Column-wise Concatenation**: Add new columns from another DataFrame.
#
#
#
# **1. Row-wise Concatenation**
#
# You can stack two DataFrames vertically to combine their rows:

# %%
# Creating a second DataFrame
data2 = {
    "Restaurant": ["R5", "R6"],
    "Votes": [90, 110],
    "Rating": [3.8, 4.3]
}

df2 = pd.DataFrame(data2)
combined_df=pd.concat([sample_df,df2],ignore_index=True)
print(combined_df)
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0
# 4         R7    150     3.7
# 5         R5     90     3.8
# 6         R6    110     4.3

# %% [markdown]
# **2. Column-wise Concatenation**
#
# You can stack DataFrames side-by-side to add new columns:

# %%
col_data={'delivery_time':[30,25,26,45,40]}
col_data_df=pd.DataFrame(col_data)
combined_col_df=pd.concat([combined_df,col_data_df],axis=1)
print(combined_col_df)
# Out:
#   Restaurant  Votes  Rating  delivery_time
# 0         R1    120     4.1           30.0
# 1         R2    300     4.7           25.0
# 2         R3    180     4.2           26.0
# 3         R4     80     4.0           45.0
# 4         R7    150     3.7           40.0
# 5         R5     90     3.8            NaN
# 6         R6    110     4.3            NaN

# %%
new_row=pd.DataFrame([['R7',150,3.7]],columns=sample_df.columns)
sample_df=pd.concat([sample_df,new_row],ignore_index=True)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0
# 4         R7    150     3.7
# 5         R7    150     3.7

# %%
combined_col_df
# Out:
#   Restaurant  Votes  Rating  delivery_time
# 0         R1    120     4.1           30.0
# 1         R2    300     4.7           25.0
# 2         R3    180     4.2           26.0
# 3         R4     80     4.0           45.0
# 4         R7    150     3.7           40.0
# 5         R5     90     3.8            NaN
# 6         R6    110     4.3            NaN

# %%
updated_rating=combined_col_df.loc[combined_col_df['Votes']>200,'Rating']
updated_rating
# Out:
# 1    4.7
# Name: Rating, dtype: float64

# %% [markdown]
# ---
#
# ## **6. 🗑️ Handling Duplicate Records in a DataFrame**
#
# In real-world datasets, duplicate records are common and can affect analysis. Pandas provides simple methods to identify and remove duplicates efficiently.
#
#
# ### **Key Methods for Handling Duplicates**

# %% [markdown]
# ### **1. Identifying Duplicate Rows with `df.duplicated()`**
#
# The `df.duplicated()` method:
# - Returns `True` for duplicate rows (excluding the first occurrence by default).
# - You can customize its behavior using the `keep` parameter:
#   - `keep='first'` (default): Marks all duplicates except the first occurrence.
#   - `keep='last'`: Marks all duplicates except the last occurrence.
#   - `keep=False`: Marks **all** duplicates as `True`.

# %%
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    300     4.7
# 2         R3    180     4.2
# 3         R4     80     4.0
# 4         R7    150     3.7
# 5         R7    150     3.7

# %%
# Example DataFrame
data = {
    "Restaurant": ["R1", "R2", "R3", "R2", "R4", "R1"],
    "Votes": [120, 240, 150, 240, 80, 120],
    "Rating": [4.1, 4.5, 3.9, 4.5, 4.0, 4.1]
}

sample_df = pd.DataFrame(data)
sample_df
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 3         R2    240     4.5
# 4         R4     80     4.0
# 5         R1    120     4.1

# %%
sample_df.duplicated()# default='first'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sample_df.duplicated(keep='last')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
sample_df.duplicated(keep=False)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# ### **2. Removing Duplicate Rows**
#
# The `df.drop_duplicates()` method removes duplicate rows based on the specified conditions:
# - By default, it keeps the first occurrence of each duplicate row.
# - You can use the `keep` parameter to change this behavior.

# %%
df_no_duplicates=sample_df.drop_duplicates(keep='first')

# %%
df_no_duplicates
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %% [markdown]
# ### **3. Removing Duplicates Based on Specific Columns**
#
# Sometimes, you might want to check duplicates only for certain columns. Use the `subset` parameter in `df.drop_duplicates()` to specify the columns to consider for duplication.
#
# - Use `subset` in `df.drop_duplicates()` to check duplicates for specific columns.

# %%
df_no_duplicates_multi_subset=sample_df.drop_duplicates(subset=['Restaurant','Votes'],keep='first')
df_no_duplicates_multi_subset
# Out:
#   Restaurant  Votes  Rating
# 0         R1    120     4.1
# 1         R2    240     4.5
# 2         R3    150     3.9
# 4         R4     80     4.0

# %% [markdown]
# ---
#
# ## **7. 📊 Pandas Built-In Operations: Aggregate Functions**

# %%
print(df.Total_votes.sum())
# Out:
# 13940720

# %%
df.Total_votes.count()
# Out:
# np.int64(23193)

# %%
df['approx_cost(for two people)']
# Out:
# 0         '800.0'
# 1         '800.0'
# 2         '800.0'
# 3         '300.0'
# 4         '600.0'
#            ...
# 23188    '1200.0'
# 23189    '2000.0'
# 23190    '1200.0'
# 23191     '800.0'
# 23192    '2500.0'
# Name: approx_cost(for two people), Length: 23193, dtype: object

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].str.replace("'",'')
df['approx_cost(for two people)']=df['approx_cost(for two people)'].str.replace(',','')
df['approx_cost(for two people)']=df['approx_cost(for two people)'].astype(float)

# %%
df['approx_cost(for two people)']
# Out:
# 0         800.0
# 1         800.0
# 2         800.0
# 3         300.0
# 4         600.0
#           ...
# 23188    1200.0
# 23189    2000.0
# 23190    1200.0
# 23191     800.0
# 23192    2500.0
# Name: approx_cost(for two people), Length: 23193, dtype: float64

# %%
df['approx_cost(for two people)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 23193 entries, 0 to 23192
# Series name: approx_cost(for two people)
# Non-Null Count  Dtype
# --------------  -----
# 23193 non-null  float64
# dtypes: float64(1)
# memory usage: 181.3 KB

# %%
# Aggregating multiple columns
aggregates = df[["Total_votes", "approx_cost(for two people)"]].agg(["sum", "mean", "min", "max"])
print("Aggregates for Votes and Cost for Two:")
aggregates
# Out:
# Aggregates for Votes and Cost for Two:
#        Total_votes  approx_cost(for two people)
# sum   1.394072e+07                 1.753169e+07
# mean  6.010745e+02                 7.559044e+02
# min   0.000000e+00                 4.000000e+01
# max   1.683200e+04                 6.000000e+03

# %% [markdown]
# ---
#
# ## **8. 🔀 Sorting Values in Pandas**
#
# ### **Sorting by a Single Column**

# %%
sorted_values_asc=sample_df.sort_values(by='Votes',ascending=True)
sorted_values_asc
# Out:
#   Restaurant  Votes  Rating
# 4         R4     80     4.0
# 0         R1    120     4.1
# 5         R1    120     4.1
# 2         R3    150     3.9
# 3         R2    240     4.5
# 1         R2    240     4.5

# %%
# Sorting rows by the "Votes" column in descending order
sorted_votes_desc = sample_df.sort_values(by="Votes", ascending=False)
print("DataFrame sorted by Votes (descending):")
print(sorted_votes_desc)
# Out:
# DataFrame sorted by Votes (descending):
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 2         R3    150     3.9
# 0         R1    120     4.1
# 5         R1    120     4.1
# 4         R4     80     4.0

# %% [markdown]
# Sort the DataFrame by "Rating" in descending order.

# %%
sorted_rating_dsc=sample_df.sort_values(by='Rating',ascending=False)
sorted_rating_dsc
# Out:
#   Restaurant  Votes  Rating
# 1         R2    240     4.5
# 3         R2    240     4.5
# 0         R1    120     4.1
# 5         R1    120     4.1
# 4         R4     80     4.0
# 2         R3    150     3.9

# %% [markdown]
# Find the restaurant with the highest rating after sorting.

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23190                             Keys Cafe - Keys Hotel           No
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  Total_votes                             phone  \
# 0            Yes          775    080 42297555\r\n+91 9743772233
# 1             No          787                      080 41714161
# 2             No          918                    +91 9663487993
# 3             No           88                    +91 9620009302
# 4             No          166  +91 8026612447\r\n+91 9901210005
# ...          ...          ...                               ...
# 23188        Yes          128    +91 7625087121\n+91 8050587483
# 23189         No           77                      080 49435000
# 23190         No          161      080 39451000\n+91 8884038484
# 23191         No           81                      080 65951222
# 23192        Yes          236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23188                  Whitefield   Bar, Casual Dining
# 23189                  Whitefield     Fine Dining, Bar
# 23190                  Whitefield   Casual Dining, Bar
# 23191                  Whitefield   Casual Dining, Bar
# 23192  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23188  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                   Rooftop Ambience
# 23190  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                               Biryani, Andhra Meal
# 23192                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 23188     North Indian, Continental, Mediterranean
# 23189                                  Finger Food
# 23190           Chinese, Continental, North Indian
# 23191  Andhra, South Indian, Chinese, North Indian
# 23192                                  Finger Food
#
#        approx_cost(for two people)  \
# 0                            800.0
# 1                            800.0
# 2                            800.0
# 3                            300.0
# 4                            600.0
# ...                            ...
# 23188                       1200.0
# 23189                       2000.0
# 23190                       1200.0
# 23191                        800.0
# 23192                       2500.0
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 23188  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 23189  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 23190  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 23191  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 23192  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city) only_rating  total_votes_by_1000  \
# 0              Buffet    Banashankari         4.1                0.775
# 1              Buffet    Banashankari         4.1                0.787
# 2              Buffet    Banashankari         3.8                0.918
# 3              Buffet    Banashankari         3.7                0.088
# 4              Buffet    Banashankari         3.8                0.166
# ...               ...             ...         ...                  ...
# 23188   Pubs and bars      Whitefield        3.8                 0.128
# 23189   Pubs and bars      Whitefield        3.9                 0.077
# 23190   Pubs and bars      Whitefield        2.8                 0.161
# 23191   Pubs and bars      Whitefield        2.5                 0.081
# 23192   Pubs and bars      Whitefield        4.3                 0.236
#
#        is_good
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
# ...        ...
# 23188    False
# 23189    False
# 23190    False
# 23191    False
# 23192    False
#
# [23193 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23193 entries, 0 to 23192
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23193 non-null  object
#  1   address                      23193 non-null  object
#  2   name                         23193 non-null  object
#  3   online_order                 23193 non-null  object
#  4   book_table                   23193 non-null  object
#  5   Total_votes                  23193 non-null  int64
#  6   phone                        23193 non-null  object
#  7   location                     23193 non-null  object
#  8   rest_type                    23193 non-null  object
#  9   dish_liked                   23193 non-null  object
#  10  cuisines                     23193 non-null  object
#  11  approx_cost(for two people)  23193 non-null  float64
#  12  reviews_list                 23193 non-null  object
#  13  menu_item                    23193 non-null  object
#  14  listed_in(type)              23193 non-null  object
#  15  listed_in(city)              23193 non-null  object
#  16  only_rating                  23193 non-null  object
#  17  total_votes_by_1000          23193 non-null  float64
#  18  is_good                      23193 non-null  bool
# dtypes: bool(1), float64(2), int64(1), object(15)
# memory usage: 3.2+ MB

# %%
df['only_rating'].unique()
# Out:
# array(['4.1', '3.8', '3.7', '4.6', '4.0', '4.2', '3.9', '3.0', '3.6',
#        '2.8', '4.4', '3.1', '4.3', '2.6', '3.3', '3.5', '3.8 ', '3.2',
#        '4.5', '2.5', '2.9', '3.4', '2.7', '4.7', 'N', '2.4', '2.2', '2.3',
#        '4.8', '3.9 ', '4.2 ', '4.0 ', '4.1 ', '2.9 ', '2.7 ', '2.5 ',
#        '2.6 ', '4.5 ', '4.3 ', '3.7 ', '4.4 ', '4.9', '2.1', '2.0', '1.8',
#        '3.4 ', '3.6 ', '3.3 ', '4.6 ', '4.9 ', '3.2 ', '3.0 ', '2.8 ',
#        '3.5 ', '3.1 ', '4.8 ', '2.3 ', '4.7 ', '2.4 ', '2.1 ', '2.2 ',
#        '2.0 ', '1.8 '], dtype=object)

# %%
df['rating_der']=

# %%
df_new=df[df['only_rating']=='N'].index
df_new=df.drop(df_new,axis=0)

df_new['only_rating']=df_new['only_rating'].astype(float)
df_new['Total_votes']=df_new['Total_votes'].astype(int)
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23046 entries, 0 to 23192
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          23046 non-null  object
#  1   address                      23046 non-null  object
#  2   name                         23046 non-null  object
#  3   online_order                 23046 non-null  object
#  4   book_table                   23046 non-null  object
#  5   Total_votes                  23046 non-null  int64
#  6   phone                        23046 non-null  object
#  7   location                     23046 non-null  object
#  8   rest_type                    23046 non-null  object
#  9   dish_liked                   23046 non-null  object
#  10  cuisines                     23046 non-null  object
#  11  approx_cost(for two people)  23046 non-null  float64
#  12  reviews_list                 23046 non-null  object
#  13  menu_item                    23046 non-null  object
#  14  listed_in(type)              23046 non-null  object
#  15  listed_in(city)              23046 non-null  object
#  16  only_rating                  23046 non-null  float64
#  17  total_votes_by_1000          23046 non-null  float64
#  18  is_good                      23046 non-null  bool
# dtypes: bool(1), float64(3), int64(1), object(14)
# memory usage: 3.4+ MB

# %%
df_new['rating_der'] = df_new['only_rating'] * df_new['Total_votes']
df_new
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 23188  https://www.zomato.com/bangalore/izakaya-gastr...
# 23189  https://www.zomato.com/bangalore/m-bar-bengalu...
# 23190  https://www.zomato.com/bangalore/keys-cafe-key...
# 23191  https://www.zomato.com/bangalore/bhagini-2-whi...
# 23192  https://www.zomato.com/bangalore/chime-sherato...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 23188  2nd Floor, Iona, Virginia Mall, Whitefield Mai...
# 23189  Bengaluru Marriott Hotel, 75, 8th Road, EPIP A...
# 23190  Keys Hotel, 6, 1st Phase Industrial Area, Near...
# 23191  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 23192  Sheraton Grand Bengaluru Whitefield Hotel & Co...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 23188                                 Izakaya Gastro Pub          Yes
# 23189        M Bar - Bengaluru Marriott Hotel Whitefield           No
# 23190                             Keys Cafe - Keys Hotel           No
# 23191                                            Bhagini           No
# 23192  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
#
#       book_table  Total_votes                             phone  \
# 0            Yes          775    080 42297555\r\n+91 9743772233
# 1             No          787                      080 41714161
# 2             No          918                    +91 9663487993
# 3             No           88                    +91 9620009302
# 4             No          166  +91 8026612447\r\n+91 9901210005
# ...          ...          ...                               ...
# 23188        Yes          128    +91 7625087121\n+91 8050587483
# 23189         No           77                      080 49435000
# 23190         No          161      080 39451000\n+91 8884038484
# 23191         No           81                      080 65951222
# 23192        Yes          236                      080 49652769
#
#                          location            rest_type  \
# 0                    Banashankari        Casual Dining
# 1                    Banashankari        Casual Dining
# 2                    Banashankari  Cafe, Casual Dining
# 3                    Banashankari          Quick Bites
# 4                    Basavanagudi        Casual Dining
# ...                           ...                  ...
# 23188                  Whitefield   Bar, Casual Dining
# 23189                  Whitefield     Fine Dining, Bar
# 23190                  Whitefield   Casual Dining, Bar
# 23191                  Whitefield   Casual Dining, Bar
# 23192  ITPL Main Road, Whitefield                  Bar
#
#                                               dish_liked  \
# 0      Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1      Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2      Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                            Masala Dosa
# 4                                    Panipuri, Gol Gappe
# ...                                                  ...
# 23188  Beer, Chicken Guntur, Paneer Tikka, Fish, Nood...
# 23189                                   Rooftop Ambience
# 23190  Salads, Coffee, Breakfast Buffet, Halwa, Chick...
# 23191                               Biryani, Andhra Meal
# 23192                       Cocktails, Pizza, Buttermilk
#
#                                           cuisines  \
# 0                   North Indian, Mughlai, Chinese
# 1                      Chinese, North Indian, Thai
# 2                           Cafe, Mexican, Italian
# 3                       South Indian, North Indian
# 4                         North Indian, Rajasthani
# ...                                            ...
# 23188     North Indian, Continental, Mediterranean
# 23189                                  Finger Food
# 23190           Chinese, Continental, North Indian
# 23191  Andhra, South Indian, Chinese, North Indian
# 23192                                  Finger Food
#
#        approx_cost(for two people)  \
# 0                            800.0
# 1                            800.0
# 2                            800.0
# 3                            300.0
# 4                            600.0
# ...                            ...
# 23188                       1200.0
# 23189                       2000.0
# 23190                       1200.0
# 23191                        800.0
# 23192                       2500.0
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 23188  [('Rated 3.0', "RATED\n  Nice place to hangout...        []
# 23189  [('Rated 4.0', 'RATED\n  Went there post dinne...        []
# 23190  [('Rated 3.0', 'RATED\n  Place is good not tha...        []
# 23191  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 23192  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
#
#       listed_in(type) listed_in(city)  only_rating  total_votes_by_1000  \
# 0              Buffet    Banashankari          4.1                0.775
# 1              Buffet    Banashankari          4.1                0.787
# 2              Buffet    Banashankari          3.8                0.918
# 3              Buffet    Banashankari          3.7                0.088
# 4              Buffet    Banashankari          3.8                0.166
# ...               ...             ...          ...                  ...
# 23188   Pubs and bars      Whitefield          3.8                0.128
# 23189   Pubs and bars      Whitefield          3.9                0.077
# 23190   Pubs and bars      Whitefield          2.8                0.161
# 23191   Pubs and bars      Whitefield          2.5                0.081
# 23192   Pubs and bars      Whitefield          4.3                0.236
#
#        is_good  rating_der
# 0         True      3177.5
# 1         True      3226.7
# 2         True      3488.4
# 3        False       325.6
# 4        False       630.8
# ...        ...         ...
# 23188    False       486.4
# 23189    False       300.3
# 23190    False       450.8
# 23191    False       202.5
# 23192    False      1014.8
#
# [23046 rows x 20 columns]

# %%
df_new[['name','rating_der']][df_new['rating_der']==df_new['rating_der'].max()]
# Out:
#                               name  rating_der
# 22232  Byg Brewski Brewing Company     82476.8
# 22364  Byg Brewski Brewing Company     82476.8
# 22531  Byg Brewski Brewing Company     82476.8

# %%
df_new.sort_values(by=['approx_cost(for two people)','Total_votes'],ascending=[True,False])
# Out:
#                                                      url  \
# 14449  https://www.zomato.com/bangalore/srinidhi-saga...
# 7774   https://www.zomato.com/bangalore/srinidhi-saga...
# 6455   https://www.zomato.com/bangalore/srinidhi-saga...
# 2220   https://www.zomato.com/bangalore/srinidhi-saga...
# 5371   https://www.zomato.com/bangalore/srinidhi-saga...
# ...                                                  ...
# 18600  https://www.zomato.com/bangalore/malties-radis...
# 18783  https://www.zomato.com/bangalore/malties-radis...
# 18085  https://www.zomato.com/bangalore/royal-afghan-...
# 20551  https://www.zomato.com/bangalore/le-cirque-sig...
# 8473   https://www.zomato.com/bangalore/le-cirque-sig...
#
#                                                  address  \
# 14449  4, 19th Main Road, 6th Cross, Kodihalli, Old A...
# 7774   4, 19th Main Road, 6th Cross, Kodihalli, Old A...
# 6455   68, Appareddy Palya, Near ESI Hospital, HAL 2n...
# 2220   68, Appareddy Palya, Near ESI Hospital, HAL 2n...
# 5371   68, Appareddy Palya, Near ESI Hospital, HAL 2n...
# ...                                                  ...
# 18600  Radisson Blu, 90/4, Outer Ring Road, Munnekoll...
# 18783  Radisson Blu, 90/4, Outer Ring Road, Munnekoll...
# 18085  ITC Windsor, 25 Windsor Square, Sankey Road, B...
# 20551  The Leela Palace, 23, Old Airport Road, Bangalore
# 8473   The Leela Palace, 23, Old Airport Road, Bangalore
#
#                                          name online_order book_table  \
# 14449                          Srinidhi Sagar          Yes         No
# 7774                           Srinidhi Sagar          Yes         No
# 6455                 Srinidhi Sagar Food Line          Yes         No
# 2220                 Srinidhi Sagar Food Line          Yes         No
# 5371                 Srinidhi Sagar Food Line          Yes         No
# ...                                       ...          ...        ...
# 18600                  Malties - Radisson Blu           No         No
# 18783                  Malties - Radisson Blu           No         No
# 18085              Royal Afghan - ITC Windsor           No        Yes
# 20551  Le Cirque Signature - The Leela Palace           No        Yes
# 8473   Le Cirque Signature - The Leela Palace           No        Yes
#
#        Total_votes                         phone          location  \
# 14449          162                  080 25219337  Old Airport Road
# 7774           160                  080 25219337  Old Airport Road
# 6455           131                  080 25250408       Indiranagar
# 2220           129                  080 25250408       Indiranagar
# 5371           129                  080 25250408       Indiranagar
# ...            ...                           ...               ...
# 18600           53                  080 49652584      Marathahalli
# 18783           53                  080 49652584      Marathahalli
# 18085          413                  080 61401227       Sankey Road
# 20551          128    080 30571234\n080 30571540  Old Airport Road
# 8473           126  080 30571234\r\n080 30571540  Old Airport Road
#
#          rest_type                                         dish_liked  \
# 14449  Quick Bites  Masala Dosa, Rava Dosa, Rava Idli, Filter Coff...
# 7774   Quick Bites  Masala Dosa, Rava Dosa, Rava Idli, Filter Coff...
# 6455   Quick Bites                   Vada, Masala Dosa, Filter Coffee
# 2220   Quick Bites                   Vada, Masala Dosa, Filter Coffee
# 5371   Quick Bites                   Vada, Masala Dosa, Filter Coffee
# ...            ...                                                ...
# 18600       Lounge  Cocktails, Jumbo Prawns, Charcuterie Platter, ...
# 18783       Lounge  Cocktails, Jumbo Prawns, Charcuterie Platter, ...
# 18085  Fine Dining  Dal Bukhara, Chocolate Cake, Butter Chicken, N...
# 20551  Fine Dining  Wine, Asparagus Soup, Creme Brulee, Pasta, Rav...
# 8473   Fine Dining  Wine, Asparagus Soup, Creme Brulee, Pasta, Rav...
#
#                                   cuisines  approx_cost(for two people)  \
# 14449  South Indian, North Indian, Chinese                         40.0
# 7774   South Indian, North Indian, Chinese                         40.0
# 6455   South Indian, North Indian, Chinese                         40.0
# 2220   South Indian, North Indian, Chinese                         40.0
# 5371   South Indian, North Indian, Chinese                         40.0
# ...                                    ...                          ...
# 18600               Continental, Fast Food                       4500.0
# 18783               Continental, Fast Food                       4500.0
# 18085                North Indian, Mughlai                       5000.0
# 20551                      French, Italian                       6000.0
# 8473                       French, Italian                       6000.0
#
#                                             reviews_list  \
# 14449  [('Rated 4.0', 'RATED\n  Ordered vada sambhar ...
# 7774   [('Rated 4.0', 'RATED\n  Ordered vada sambhar ...
# 6455   [('Rated 4.0', 'RATED\n  Affordable price. If ...
# 2220   [('Rated 4.0', "RATED\n  Love their masala dos...
# 5371   [('Rated 4.0', "RATED\n  Love their masala dos...
# ...                                                  ...
# 18600  [('Rated 3.0', "RATED\n  We had visited this p...
# 18783  [('Rated 3.0', "RATED\n  We had visited this p...
# 18085  [('Rated 5.0', 'RATED\n  It is just Bukhara wi...
# 20551  [('Rated 5.0', 'RATED\n  Awesome would be an u...
# 8473   [('Rated 5.0', 'RATED\n  Awesome would be an u...
#
#                                                menu_item     listed_in(type)  \
# 14449                                                 []            Delivery
# 7774                                                  []            Delivery
# 6455   ['2 Idly and 1 Vada', 'Rice Bath', 'Poori', 'M...            Delivery
# 2220   ['2 Idly and 1 Vada', 'Rice Bath', 'Poori', 'M...            Delivery
# 5371   ['2 Idly and 1 Vada', 'Rice Bath', 'Poori', 'M...            Delivery
# ...                                                  ...                 ...
# 18600                                                 []            Dine-out
# 18783                                                 []  Drinks & nightlife
# 18085                                                 []            Dine-out
# 20551                                                 []            Dine-out
# 8473                                                  []            Dine-out
#
#              listed_in(city)  only_rating  total_votes_by_1000  is_good
# 14449  Koramangala 6th Block          3.9                0.162    False
# 7774             Indiranagar          3.9                0.160    False
# 6455             Frazer Town          3.7                0.131    False
# 2220            Brigade Road          3.7                0.129    False
# 5371           Church Street          3.7                0.129    False
# ...                      ...          ...                  ...      ...
# 18600           Marathahalli          4.3                0.053    False
# 18783           Marathahalli          4.3                0.053    False
# 18085           Malleshwaram          4.3                0.413    False
# 20551       Old Airport Road          4.3                0.128    False
# 8473             Indiranagar          4.3                0.126    False
#
# [23046 rows x 19 columns]

# %% [markdown]
# Create a new sorted DataFrame based on "Votes" and "Rating" and display the top 3 rows.

# %%
df_new.sort_values(by=['Total_votes','only_rating']).head(3)
# Out:
#                                                     url  \
# 9483  https://www.zomato.com/bangalore/baba-chatkora...
# 9479  https://www.zomato.com/bangalore/nourich-jp-na...
# 3584  https://www.zomato.com/bangalore/tangerine-dav...
#
#                                                 address  \
# 9483  1304, Ground Floor, 9th Cross, 20th Main, JP N...
# 9479  67, Ground Floor, 3rd E Main Road, 15th Cross ...
# 3584  Davanam Plaza, Next To Total Mall Madivala, Ho...
#
#                                             name online_order book_table  \
# 9483                               Baba Chatkora          Yes         No
# 9479                                     Nourich          Yes        Yes
# 3584  Tangerine - Davanam Sarovar Portico Suites          Yes        Yes
#
#       Total_votes                             phone               location  \
# 9483            0                    +91 9880894199               JP Nagar
# 9479            0  +91 9945675038\r\n+91 8970112299               JP Nagar
# 3584            0                      080 49652825  Koramangala 2nd Block
#
#           rest_type                                         dish_liked  \
# 9483  Casual Dining                    Dal Makhani, Thali, Matka Lassi
# 9479  Casual Dining  Soba Noodles, Pad Thai Noodle, Pickled Beetroo...
# 3584  Casual Dining  Breakfast Buffet, Sushi, Cheesecake, Gulab Jam...
#
#                                                cuisines  \
# 9483                                       North Indian
# 9479  Continental, Chinese, North Indian, Asian, Hea...
# 3584  Continental, Italian, North Indian, Asian, Bak...
#
#       approx_cost(for two people)  \
# 9483                       1000.0
# 9479                        800.0
# 3584                       1100.0
#
#                                            reviews_list  \
# 9483  [('Rated 5.0', 'RATED\n  As always my goto ord...
# 9479  [('Rated 3.0', 'RATED\n  Located in JP Nagar 3...
# 3584  [('Rated 3.0', "RATED\n  I tried out a lot of ...
#
#                                               menu_item listed_in(type)  \
# 9483                                                 []        Dine-out
# 9479  ['Murg Malai Kebab', 'Tangdi Kebab', 'Goan Fis...        Dine-out
# 3584                                                 []          Buffet
#
#      listed_in(city)  only_rating  total_votes_by_1000  is_good
# 9483       Jayanagar          3.7                  0.0    False
# 9479       Jayanagar          3.9                  0.0    False
# 3584             BTM          4.0                  0.0    False
